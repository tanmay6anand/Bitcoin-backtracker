# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = pd.read_csv("results.txt",
                 delimiter=" ", dtype=str)

# %%
display(arr)
# Out:
#       MON timestamp weightedPrice   RollingMin   RollingMax    averPrice  \
# 0     MON        30       14156.4      14156.4      14156.4      14156.4
# 1     MON        31       13657.2      11833.0      20089.0      13657.2
# 2     MON        32       14982.1      11833.0      20089.0      14982.1
# 3     MON        33       15201.0      11833.0      20089.0      15201.0
# 4     MON        34       15599.2      11833.0      20089.0      15599.2
# ...   ...       ...           ...          ...          ...          ...
# 1842  MON      1872   21169.63281  16408.47461  21075.14258  21169.63281
# 1843  MON      1873   21161.51953  16408.47461    21360.875  21161.51953
# 1844  MON      1874   20688.78125  16408.47461  21438.66016  20688.78125
# 1845  MON      1875   21086.79297  16408.47461  21564.50195  21086.79297
# 1846  MON      1876   21086.79297  16408.47461  21564.50195  21086.79297
#
#      stdevPrice                coin    cash       curBalanceCoin  \
# ...

# %%
print(arr.values)
# Out:
# [['MON' '30' '14156.4' ... '1000.0' '0' '0']
#  ['MON' '31' '13657.2' ... '1000.0' '0' '0']
#  ['MON' '32' '14982.1' ... '1000.0' '0' '0']
#  ...
#  ['MON' '1874' '20688.78125' ... '10912.377679871166' '27' '0']
#  ['MON' '1875' '21086.79297' ... '11122.310500812715' '27' '0']
#  ['MON' '1876' '21086.79297' ... '11122.310500812715' '27' '0']]

# %%
x = arr[timestamp]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_24932/1243648402.py in <module>
# ----> 1 x = arr[timestamp]
#
# NameError: name 'timestamp' is not defined

# %%
arr.hist(column='timestamp',by='curBalanceDollar',sharex=True)
# Out:
# array([[<AxesSubplot:title={'center':'1000.0'}>,
#         <AxesSubplot:title={'center':'1000.3361691157515'}>,
#         <AxesSubplot:title={'center':'1001.2490620597566'}>,
#         <AxesSubplot:title={'center':'1001.6565147020685'}>,
#         <AxesSubplot:title={'center':'1004.780613560196'}>,
#         <AxesSubplot:title={'center':'1013.4489478208748'}>,
#         <AxesSubplot:title={'center':'10135.163349985458'}>,
#         <AxesSubplot:title={'center':'10136.9209897944'}>,
#         <AxesSubplot:title={'center':'1016.5661252900231'}>,
#         <AxesSubplot:title={'center':'10168.365407350153'}>,
#         <AxesSubplot:title={'center':'10197.383829623794'}>,
#         <AxesSubplot:title={'center':'10199.379740757897'}>,
#         <AxesSubplot:title={'center':'10222.920593850982'}>,
#         <AxesSubplot:title={'center':'10261.286999346463'}>,
#         <AxesSubplot:title={'center':'10333.835894681737'}>,
#         <AxesSubplot:title={'center':'10336.396650807874'}>,
# ...
